# %% [markdown]
# # Exploratory data analysis 2
#
# **INPUT**: Preprocessed train, validation, test corpora
#
# **OUTPUT**: Preprocessing validation, tokenizer parameter decisions
#
# | Step | Decision | Status | Comment |
# |------|----------|--------|---------|
# | Preprocessing impact | - | Pending | Message length distribution, count of removed messages |
# | Class distribution | - | Pending | - |
# | Vocabulary size estimation | - | Pending | - |
# | Length statistics for tokenizer | - | Pending | - |
